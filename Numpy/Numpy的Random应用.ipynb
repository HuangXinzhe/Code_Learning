# 49
# 17
# 63
# 17
# 1
# 38
# 68
# 43
# 32
# 73
# 95
# 74
# 24
# 89
# 37
# 7
# 36
# 76
# 67
# 64
# 54
# 93
# 10
# 33
# 27
# 69
# 13
# 60
# 2
# 55
# 34
# 70
# 27
# 12
# 32
# 64
# 76
# 51
# 42
# 32
# 71
# 83
# 47
# 28
# 11
# 98
# 44
# 88
# 41
# 28
# 27
# 26
# 94
# 12
# 56
# 71
# 79
# 69
# 51
# 59
# 70
# 73
# 6
# 63
# 24
# 75
# 3
# 69
# 30
# 8
# 29
# 22
# 20
# 57
# 12
# 55
# 59
# 78
# 84
# 35
# 11
# 50
# 31
# 32
# 61
# 66
# 94
# 69
# 42
# 26
# 51
# 70
# 15
# 80
# 1
# 89
# 85
# 68
# 41
# 85
# 9
# 76
# 80
# 89
# 51
# 39
# 50
# 92
# 76
# 14
# 7
# 82
# 41
# 65
# 79
# 51
# 68
# 46
# 1
# 37
# 55
# 45
# 96
# 57
# 34
# 12
# 37
# 34
# 59
# 78
# 44
# 47
# 59
# 11
# 58
# 19
# 21
# 9
# 74
# 17
# 33
# 69
# 56
# 28
# 88
# 41
# 84
# 43
# 74
# 62
# 62
# 40
# 3
# 99
# 84
# 29
# 70
# 54
# 40
# 53
# 53
# 14
# 97
# 35
# 18
# 51
# 72
# 27
# 22
# 80
# 88
# 83
# 68
# 24
# 92
# 59
# 75
# 53
# 38
# 40
# 76
# 90
# 72
# 45
# 26
# 65
# 60
# 79
# 51
# 5
# 16
# 36
# 25
# 96
# 18
# 99
# 64
# 30
# 85
# 41
# 39
# 22
# 88
# 74
# 63
# 81
# 2
# 46
# 44
# 93
# 69
# 67
# 59
# 54
# 88
# 46
# 80
# 12
# 21
# 96
# 40
# 60
# 15
# 33
# 31
# 44
# 86
# 84
# 53
# 98
# 12
# 74
# 41
# 41
# 16
# 79
# 62
# 97
# 99
# 72
# 89
# 77
# 70
# 72
# 58
# 25
# 20
# 57
# 81
# 56
# 6
# 25
# 67
# 4
# 71
# 75
# 81
# 98
# 32
# 55
# 97
# 7
# 37
# 57
# 37
# 67
# 86
# 18
# 36
# 24
# 65
# 15
# 12
# 70
# 24
# 4
# 88
# 1
# 69
# 37
# 14
# 93
# 82
# 22
# 51
# 34
# 88
# 94
# 47
# 14
# 44

# %%
from numpy import random

x = random.rand() # random generator for float (0,1)

print(x)
# Out:
# 0.42109739694118176

# %%
# Generate a 1-D array containing 5 random integers from 0 to 100:


from numpy import random

x=random.randint(100, size=(10))

x
# Out:
# array([66, 28, 78, 99, 59, 84, 46, 28, 50, 50])

# %%
from numpy import random

x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[34 11 99 87 51]
#  [ 6 53 76 80 47]
#  [42 26 19 11 41]]

# %%
from numpy import random

x = random.rand(5)

print(x)

# 问题： random.rand() generate (0,1), 
#.      how to generate (3,5) float?
#       random.rand()*2 + 3
# Out:
# [0.80490161 0.25559631 0.10994091 0.54529727 0.90402552]

# %%
from numpy import random

x = random.rand(3, 5)

print(x)
# Out:
# [[0.68305249 0.95643184 0.25785266 0.93712528 0.66882984]
#  [0.16244408 0.71459152 0.2970599  0.52182856 0.53745195]
#  [0.18629484 0.54283457 0.85748126 0.3445783  0.10147087]]

# %% [markdown]
# #### Generate Random Number From Array
# The ```choice()``` method allows you to generate a random value based on an array of values.
#
# The choice() method takes an array as a parameter and randomly returns one of the values.

# %%
from numpy import random

for i in range(20):
    x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0])

    print(x)
# Out:
# 5
# 7
# 5
# 7
# 7
# 3
# 5
# 7
# 7
# 7
# 5
# 7
# 5
# 7
# 7
# 5
# 7
# 5
# 3
# 7

# %%
from numpy import random
# Generate a 2-D array that consists of the values in the array parameter (3, 5, 7, and 9):
x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[3 5 9 7 9]
#  [9 5 5 5 7]
#  [5 5 3 9 5]]

# %%
from numpy import random
# 给定每个值被选中的概率，从这个数字中采样数字： multinomial distribution
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3,5))

print(x)
# Out:
# [[5 5 5 3 7]
#  [5 5 5 5 3]
#  [3 7 7 7 5]]

# %% [markdown]
# #### shuffle

# %%
# Shuffle means changing arrangement of elements in-place. i.e. in the array itself.

from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [3 1 5 2 4]

# %% [markdown]
# #### permutation

# %%
# The permutation() method returns a re-arranged array (and leaves the original array un-changed).

from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [2 1 3 5 4]

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# #### Normal Distribution
# The Normal Distribution is one of the most important distributions.
#
# It is also called the Gaussian Distribution after the German mathematician Carl Friedrich Gauss.
#
# It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.
#
# Use the random.normal() method to get a Normal Data Distribution.
#
# It has three parameters:
#
# - loc - (Mean) where the peak of the bell exists.
#
# - scale - (Standard Deviation) how flat the graph distribution should be.
#
# - size - The shape of the returned array.

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-1.04801609  0.18804217  1.68577632]
#  [ 0.96879182  0.28213075  0.918805  ]]

# %%
from numpy import random

# loc均值，scale标准差
x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 2.24920636  1.936903    0.3362537 ]
#  [ 1.9820938   2.27233986 -0.27835675]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
# matplotlib inline

sns.distplot(random.normal(size=1000), hist=50)

plt.show()
# Out:
# D:\Anaconda3\envs\pytorch_gpu\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
