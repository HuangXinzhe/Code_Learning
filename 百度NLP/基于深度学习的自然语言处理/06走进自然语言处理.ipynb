# %% [markdown]
# # 什么是自然语言处理
# 研究能实现人与计算机之间用自然语言进行有效通信的各种理论和方法，融合语言学、计算机科学、数学与一体的科学

# %% [markdown]
# # 自然语言处理有啥用
# 1. 智能问答
# 2. 智能对话
# 3. 机器同传https://tongchuan.baidu.com

# %% [markdown]
# # 自然语言处理的挑战
# - 多样性
# - 歧义性
#
# > 图灵测试
#
# 关于“理解”的标准
#
# 具体准则：
# - 问答
# - 对话
# - 翻译

# %% [markdown]
# ## 自然语言处理技术发展
# ![image.png](attachment:image.png)
# 1. 基于规则的方法
# 2. 统计学习方法
# 3. 深度学习方法

# %% [markdown]
# ![image.png](attachment:image.png)
# 依赖专家知识与理解

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# 自动学习特征

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
